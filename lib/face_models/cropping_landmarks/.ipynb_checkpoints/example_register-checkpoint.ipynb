# %%
import pickle
from register import *
import matplotlib.pyplot as plt

# %%
data = pickle.load(open('data_register.pkl','rb'))
pts = data['pts']
img = data['img']
mShape = data['mShape']

# %%
Tout, ptsout, imout = registerImage( pts, mShape, img, rotate=0)
img_crop, pts_crop = crop(imout,ptsout.getA())
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-3-ee3710cd3aaf> in <module>
# ----> 1 Tout, ptsout, imout = registerImage( pts, mShape, img, rotate=0)
#       2 img_crop, pts_crop = crop(imout,ptsout.getA())
#
# ~/Desktop/projects/voxCeleb_code/tzimi/register.py in registerImage(pts, mShape, img, rotate)
#      60     else:
#      61         c = np.array([img.shape[1]/2 + 0.5, img.shape[0]/2 + 0.5])
# ---> 62         imreg = scipy.misc.imrotate(img,rotangle, interp='bilinear')
#      63         imreg = scipy.misc.imresize(imreg, 1/T[1])
#      64         #cv2.resize(imreg.astype('float32'), None, fx=1/T[1], fy=1/T[1], interpolation=cv2.INTER_CUBIC)
#
# AttributeError: module 'scipy' has no attribute 'misc'

# %%
plt.imshow(img_crop)
plt.plot(pts_crop[:,0],pts_crop[:,1],'x')

# %%
Tout, ptsout, imout = registerImage( pts, mShape, img, rotate=1)
img_crop, pts_crop = crop(imout,ptsout.getA())
plt.imshow(img_crop)
plt.plot(pts_crop[:,0],pts_crop[:,1],'x')
